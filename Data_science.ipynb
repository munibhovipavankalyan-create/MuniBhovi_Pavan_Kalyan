# %% [markdown]
# # Final Project: Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we will summarize the tools, languages, and libraries used in Data Science. We will also perform simple arithmetic operations using Python.

# %% [markdown]
# ## Data Science Languages
# The following are some of the most popular languages used in Data Science:
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# Here are some widely used libraries in Data Science:
#
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# ## Data Science Tools
#
# | Tool              | Category                |
# |-------------------|--------------------------|
# | Jupyter Notebook  | Interactive Environment  |
# | RStudio           | IDE for R                |
# | Apache Spark      | Big Data Processing      |
# | TensorFlow        | Deep Learning Framework  |
# | Tableau           | Data Visualization       |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are examples of basic arithmetic expressions executed using Python code.

# %%
# Multiply and add numbers
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
# In this notebook, you will learn:
#
# - Popular languages used in Data Science
# - Common Data Science libraries
# - Common tools used by Data Scientists
# - How to perform arithmetic operations in Python
# - How to convert minutes to hours using Python

# %% [markdown]
# ## Author
# **ABC XYZ**
